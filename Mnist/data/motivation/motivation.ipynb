# %%
import pickle
def save_file(file_name,data):
    open_file = open(file_name, "wb")
    pickle.dump(data, open_file)
    open_file.close()

def open_file(file_name):
    open_file = open(file_name, "rb")
    Dataset = pickle.load(open_file)
    open_file.close()
    return Dataset

# %%
file_name="fedavg Mnist noniid.pkl"
fedavg=open_file(file_name)

# %%
noise=fedavg[-2]+200
print(noise)
# Out:
# [200 210 211 213 221 227 229 232 235 241 244 247 250 251 254 258 259 261
#  264 268 272 275 276 277 279 280 282 283 284 295]

# %%
shuffle=fedavg[-3]+100
print(shuffle)
# Out:
# [104 121 122 123 128 131 134 135 138 144 145 147 149 156 160 161 163 164
#  166 169 170 172 175 177 181 182 184 186 193 199]

# %%
flip=fedavg[-4]
print(flip)
# Out:
# [ 1  3  6 13 14 20 23 27 31 32 35 45 47 48 49 52 59 60 67 69 73 79 82 83
#  86 88 89 93 94 97]

# %%
loss_test=fedavg[5][-1]

# %%
loss_train=fedavg[3][1]

# %%
noiseplot=[loss_train[i] for i in noise]
flipplot=[loss_train[i] for i in flip]
shuffleplot=[loss_train[i] for i in shuffle]

# %%
result_list = []
result_list.extend(shuffle)
result_list.extend(flip)
result_list.extend(noise)

# %%
goodplot = [loss_train[i] for i in range(len(loss_train)) if i not in result_list]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Sample data for two distributions
data1 = np.random.normal(loc=0, scale=1, size=1000)
data2 = np.random.normal(loc=2, scale=1, size=1000)
data3 = np.random.normal(loc=1, scale=1, size=1000)

# Create a histogram plot
plt.figure(figsize=(8, 6))

sns.histplot(noiseplot, color='blue', label='Nosiy', kde=True)
sns.histplot(flipplot, color='orange', label='Flipping', kde=True)
sns.histplot(shuffleplot, color='green', label='Shuffling', kde=True)
sns.histplot(goodplot, color='red', label='Good', kde=True)

plt.title('Two Distributions')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Sample data for four distributions
data1 = np.random.normal(loc=0, scale=1, size=1000)
data2 = np.random.normal(loc=2, scale=1, size=1000)
data3 = np.random.normal(loc=1, scale=1, size=1000)

# Calculate medians
median1 = np.median(data1)
median2 = np.median(data2)
median3 = np.median(data3)

# Create a histogram plot
plt.figure(figsize=(8, 6))

sns.histplot(data1, color='blue', label='Noisy', kde=True)
sns.histplot(data2, color='orange', label='Flipping', kde=True)
sns.histplot(data3, color='green', label='Shuffling', kde=True)

# Plot vertical lines for medians
plt.axvline(x=median1, color='blue', linestyle='dashed', linewidth=2, label='Median (Noisy)')
plt.axvline(x=median2, color='orange', linestyle='dashed', linewidth=2, label='Median (Flipping)')
plt.axvline(x=median3, color='green', linestyle='dashed', linewidth=2, label='Median (Shuffling)')

plt.title('Distributions with Medians')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Replace these with your actual calculated loss values
algorithm1_without_FedSRC = 0.5
algorithm1_with_FedSRC = 0.3

algorithm2_without_FedSRC = 0.8
algorithm2_with_FedSRC = 0.6

algorithm3_without_FedSRC = 0.7
algorithm3_with_FedSRC = 0.4

algorithm4_without_FedSRC = 1.2
algorithm4_with_FedSRC = 0.9

# List of algorithms and their corresponding loss values
algorithms = ['Algorithm 1', 'Algorithm 2', 'Algorithm 3', 'Algorithm 4']
without_FedSRC = [algorithm1_without_FedSRC, algorithm2_without_FedSRC, algorithm3_without_FedSRC, algorithm4_without_FedSRC]
with_FedSRC = [algorithm1_with_FedSRC, algorithm2_with_FedSRC, algorithm3_with_FedSRC, algorithm4_with_FedSRC]

# Create a bar plot
plt.figure(figsize=(10, 6))
bar_width = 0.35
index = range(len(algorithms))

plt.bar(index, without_FedSRC, bar_width, label='Without FedSRC')
plt.bar([i + bar_width for i in index], with_FedSRC, bar_width, label='With FedSRC')

plt.xlabel('Algorithms')
plt.ylabel('Loss Value')
plt.title('Final Loss Values with and without FedSRC')
plt.xticks([i + bar_width/2 for i in index], algorithms)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace these with your actual calculated loss values
algorithm1_without_FedSRC = 0.5
algorithm1_with_FedSRC = 0.3

algorithm2_without_FedSRC = 0.8
algorithm2_with_FedSRC = 0.6

algorithm3_without_FedSRC = 0.7
algorithm3_with_FedSRC = 0.4

algorithm4_without_FedSRC = 1.2
algorithm4_with_FedSRC = 0.9

# List of algorithms and their corresponding loss values
algorithms = ['Algorithm 1', 'Algorithm 2', 'Algorithm 3', 'Algorithm 4']
without_FedSRC = [algorithm1_without_FedSRC, algorithm2_without_FedSRC, algorithm3_without_FedSRC, algorithm4_without_FedSRC]
with_FedSRC = [algorithm1_with_FedSRC, algorithm2_with_FedSRC, algorithm3_with_FedSRC, algorithm4_with_FedSRC]

# Set Seaborn style
sns.set(style="whitegrid")

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=algorithms, y=without_FedSRC, color='blue', label='Without FedSRC')
ax = sns.barplot(x=algorithms, y=with_FedSRC, color='orange', label='With FedSRC')

# Adding legend and labels
ax.set_xlabel('Algorithms')
ax.set_ylabel('Loss Value')
ax.set_title('Final Loss Values with and without FedSRC')
ax.legend()

plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Replace these with your actual calculated loss values
algorithm1_without_FedSRC = 0.5
algorithm1_with_FedSRC = 0.3

algorithm2_without_FedSRC = 0.8
algorithm2_with_FedSRC = 0.6

algorithm3_without_FedSRC = 0.7
algorithm3_with_FedSRC = 0.4

algorithm4_without_FedSRC = 1.2
algorithm4_with_FedSRC = 0.9

# List of algorithms and their corresponding loss values
algorithms = ['Algorithm 1', 'Algorithm 2', 'Algorithm 3', 'Algorithm 4']
data_without_FedSRC = [algorithm1_without_FedSRC, algorithm2_without_FedSRC, algorithm3_without_FedSRC, algorithm4_without_FedSRC]
data_with_FedSRC = [algorithm1_with_FedSRC, algorithm2_with_FedSRC, algorithm3_with_FedSRC, algorithm4_with_FedSRC]

# Create a DataFrame for Seaborn
df = pd.DataFrame({
    'Algorithm': algorithms,
    'Without FedSRC': data_without_FedSRC,
    'With FedSRC': data_with_FedSRC
})

# Set Seaborn style
sns.set(style="whitegrid")

# Melt the DataFrame for easier plotting
melted_df = df.melt(id_vars='Algorithm', var_name='Method', value_name='Loss Value')

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Algorithm', y='Loss Value', hue='Method', data=melted_df)

# Adding legend and labels
ax.set_xlabel('Algorithms')
ax.set_ylabel('Loss Value')
ax.set_title('Final Loss Values with and without FedSRC')
ax.legend(title='Method')

plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %%
def find_cutoff(values, percent):
    sorted_values = sorted(values)
    total_values = len(sorted_values)
    cutoff_index = int(total_values * (1-percent/100))
    cutoff_value = sorted_values[cutoff_index]
    return cutoff_value

# Example list of values
values = [10, 5, 20, 15, 30, 25, 40, 35, 50, 45]

cutoff = find_cutoff(values, 30)
print("Cutoff value for the lower 70%:", cutoff)
# Out:
# Cutoff value for the lower 70%: 40
